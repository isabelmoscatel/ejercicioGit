# %%
import pandas as pd
import matplotlib.pyplot as plt

data_path = "../data/raw/products.csv"

df = pd.read_csv(data_path)

print("Bssic Satatistics")

print(df.describe())

plt.hist(df["price"], bins=20, edgecolor="black")
plt.title("distribucion de textos")
plt.xlabel("Precio")
plt.ylabel("Frecuencia")
plt.show
print("Productos mas Caros: ")
highestPrice = df.nlargest(5,'price')
print(highestPrice)
# Out:
# Bssic Satatistics
#                    title                                        description  \
# count                  3                                                  3
# unique                 3                                                  3
# top     Acer Aspire 3...  Acer Aspire 3 A315-31 Black, 15.6" HD, Pentium...
# freq                   1                                                  1
#
#           price
# count         3
# unique        3
# top     $408.98
# freq          1
# Productos mas Caros:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 18
#      16 plt.show
#      17 print("Productos mas Caros: ")
# ---> 18 highestPrice = df.nlargest(5,'price')
#      19 print(highestPrice)
#
# File c:\Python312\Lib\site-packages\pandas\core\frame.py:7644, in DataFrame.nlargest(self, n, columns, keep)
#    7525 def nlargest(
# ...
